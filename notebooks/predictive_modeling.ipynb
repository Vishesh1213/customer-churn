# %%
# %run data_understanding.ipynb
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   str
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   str
#  3   State              7043 non-null   str
#  4   City               7043 non-null   str
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   str
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   str
#  10  Senior Citizen     7043 non-null   str
#  11  Partner            7043 non-null   str
#  12  Dependents         7043 non-null   str
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   str
#  15  Multiple Lines     7043 non-null   str
#  16  Internet Service   7043 non-null   str
# ...

# %%
# %run preprocessing.ipynb
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   str
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   str
#  3   State              7043 non-null   str
#  4   City               7043 non-null   str
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   str
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   str
#  10  Senior Citizen     7043 non-null   str
#  11  Partner            7043 non-null   str
#  12  Dependents         7043 non-null   str
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   str
#  15  Multiple Lines     7043 non-null   str
#  16  Internet Service   7043 non-null   str
# ...

# %%
df_encoded
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Value  Gender_Male  \
# 0                 2            53.85         108.15            1         True
# 1                 2            70.70         151.65            1        False
# 2                 8            99.65         820.50            1        False
# 3                28           104.80        3046.05            1        False
# 4                49           103.70        5036.30            1         True
# ...             ...              ...            ...          ...          ...
# 7038             72            21.15        1419.40            0        False
# 7039             24            84.80        1990.50            0         True
# 7040             72           103.20        7362.90            0        False
# 7041             11            29.60         346.45            0        False
# 7042             66           105.65        6844.50            0         True
#
# ...

# %%
x = df_encoded.drop(columns=['Churn Value'])
y = df_encoded['Churn Value']

# %%
x
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Gender_Male  \
# 0                 2            53.85         108.15         True
# 1                 2            70.70         151.65        False
# 2                 8            99.65         820.50        False
# 3                28           104.80        3046.05        False
# 4                49           103.70        5036.30         True
# ...             ...              ...            ...          ...
# 7038             72            21.15        1419.40        False
# 7039             24            84.80        1990.50         True
# 7040             72           103.20        7362.90        False
# 7041             11            29.60         346.45        False
# 7042             66           105.65        6844.50         True
#
#       Senior Citizen_Yes  Partner_Yes  Dependents_Yes  Phone Service_Yes  \
# 0                  False        False           False               True
# ...

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    0
# 7042    0
# Name: Churn Value, Length: 7043, dtype: int64

# %% [markdown]
# ML Implementation

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (5634, 30)

# %%
X_test.shape
# Out:
# (1409, 30)

# %%
Y_train.shape
# Out:
# (5634,)

# %%
Y_test.shape
# Out:
# (1409,)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
rf_model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_model.predict(X_test)

# %%
Y_test
# Out:
# 185     1
# 2715    0
# 3825    0
# 1807    1
# 132     1
#        ..
# 6366    0
# 315     1
# 2439    0
# 5002    0
# 1161    1
# Name: Churn Value, Length: 1409, dtype: int64

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 1], shape=(1409,))

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(Y_test, y_pred)

# %%
print(accuracy)
# Out:
# 0.7856635911994322

# %% [markdown]
# confusion matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(Y_test, y_pred)

# %%
print(cm)
# Out:
# [[902 107]
#  [195 205]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86      1009
#            1       0.66      0.51      0.58       400
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.70      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %% [markdown]
# We need to maintain the recall

# %% [markdown]
# Approach 1 - Handle Data Imbalance

# %%
rf_balanced = RandomForestClassifier(n_estimators=100, random_state=42,class_weight='balanced')
rf_balanced.fit(X_train, Y_train)
y_pred_balanced = rf_balanced.predict(X_test)
accuracy_balanced = accuracy_score(Y_test, y_pred_balanced)
cm_balanced=confusion_matrix(Y_test, y_pred_balanced)
print(accuracy_balanced)
print(cm_balanced)
print(classification_report(Y_test, y_pred_balanced))
# Out:
# 0.7885024840312278
# [[835 174]
#  [124 276]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85      1009
#            1       0.61      0.69      0.65       400
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.76      0.75      1409
# weighted avg       0.80      0.79      0.79      1409

# %% [markdown]
# Approach 2 - Hyperparameter Tuning

# %%
rf_tuned = RandomForestClassifier(n_estimators=300, max_depth=10,
                                  random_state=42,class_weight='balanced')
rf_tuned.fit(X_train, Y_train)
y_pred_tuned = rf_tuned.predict(X_test)



print(classification_report(Y_test, y_pred_tuned))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.76      0.82      1009
#            1       0.56      0.79      0.66       400
#
#     accuracy                           0.77      1409
#    macro avg       0.73      0.77      0.74      1409
# weighted avg       0.80      0.77      0.78      1409

# %%
rf_tuned1 = RandomForestClassifier(n_estimators=500, max_depth=5,
                                  random_state=42,class_weight='balanced')
rf_tuned1.fit(X_train, Y_train)
y_pred_tuned1 = rf_tuned1.predict(X_test)



print(classification_report(Y_test, y_pred_tuned1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.71      0.80      1009
#            1       0.53      0.82      0.64       400
#
#     accuracy                           0.74      1409
#    macro avg       0.72      0.77      0.72      1409
# weighted avg       0.80      0.74      0.75      1409

# %% [markdown]
# # Approach 3 - Feature importance analysis

# %%
import pandas as pd
feature_importance = pd.DataFrame({
    'Feature': x.columns,
    'Importance': rf_tuned.feature_importances_
    })
feature_importance = feature_importance.sort_values(
    by='Importance', ascending=False)
print(feature_importance)
# Out:
#                                    Feature  Importance
# 0                            Tenure Months    0.181263
# 2                            Total Charges    0.129510
# 25                       Contract_Two year    0.107095
# 1                          Monthly Charges    0.092107
# 6                           Dependents_Yes    0.069950
# 10            Internet Service_Fiber optic    0.058224
# 28         Payment Method_Electronic check    0.045804
# 24                       Contract_One year    0.036634
# 13                     Online Security_Yes    0.029029
# 19                        Tech Support_Yes    0.021449
# 26                   Paperless Billing_Yes    0.018815
# 18        Tech Support_No internet service    0.015780
# 5                              Partner_Yes    0.015526
# 12     Online Security_No internet service    0.015416
# 22    Streaming Movies_No internet service    0.014900
# 16   Device Protection_No internet service    0.014825
# ...

# %%
print(feature_importance.tail(15))
# Out:
#                                    Feature  Importance
# 16   Device Protection_No internet service    0.014825
# 15                       Online Backup_Yes    0.012650
# 3                              Gender_Male    0.012526
# 20        Streaming TV_No internet service    0.012108
# 11                     Internet Service_No    0.011753
# 9                       Multiple Lines_Yes    0.010977
# 4                       Senior Citizen_Yes    0.010775
# 23                    Streaming Movies_Yes    0.010104
# 21                        Streaming TV_Yes    0.009634
# 27  Payment Method_Credit card (automatic)    0.009211
# 17                   Device Protection_Yes    0.009133
# 14       Online Backup_No internet service    0.008657
# 29             Payment Method_Mailed check    0.008595
# 7                        Phone Service_Yes    0.004014
# 8          Multiple Lines_No phone service    0.003536

# %%
X_selected = x.drop(['Phone Service_Yes' ,'Multiple Lines_No phone service','Payment Method_Mailed check','Online Backup_No internet service',],axis=1)

# %%
X_train_selected, X_test_selected, Y_train_selected, Y_test_selected = train_test_split(X_selected, y, test_size=0.2, random_state=42)

# %%
rf_selected = RandomForestClassifier(n_estimators=300, max_depth=5,
                                  random_state=42,class_weight='balanced')
rf_selected.fit(X_train_selected, Y_train_selected)
y_pred__selected = rf_selected.predict(X_test_selected)



print(classification_report(Y_test_selected, y_pred__selected))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.71      0.80      1009
#            1       0.53      0.82      0.64       400
#
#     accuracy                           0.74      1409
#    macro avg       0.72      0.76      0.72      1409
# weighted avg       0.80      0.74      0.75      1409

# %% [markdown]
# Approach 2 - Conti.

# %%
n_estimators_list = [100,200,300,400,500]
max_depth_list = [5,10,15,20,25]
results = []
for n in n_estimators_list:
    for d in max_depth_list:
        rf_tuned = RandomForestClassifier(n_estimators=n, max_depth=d,
                                  random_state=42,class_weight='balanced')
        rf_tuned.fit(X_train, Y_train)
        y_pred_tuned = rf_tuned.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# %%
n_estimators_list = [100,200,300,400,500]
max_depth_list = [5,10,15,20,25]
results = []
for n in n_estimators_list:
    for d in max_depth_list:
        rf_tuned = RandomForestClassifier(n_estimators=n, max_depth=d,
                                  random_state=42,class_weight='balanced')
        rf_tuned.fit(X_train, Y_train)
        y_pred_tuned = rf_tuned.predict(X_test)
        accuracy = accuracy_score(Y_test, y_pred_tuned)
        recall = recall_score(Y_test, y_pred_tuned)
        precision = precision_score(Y_test, y_pred_tuned)
        f1 = f1_score(Y_test, y_pred_tuned)
        results.append({
           'Trees' : n,
           'Depth' : d,
           'Accuracy' : accuracy,
           'Recall' : recall,
           'Precision' : precision,
           'F1 score' : f1
        })
results_df = pd.DataFrame(results)
results_df = results_df.sort_values(by=['Recall', 'Accuracy'], ascending=False)
print(results_df.head(20))
# Out:
#     Trees  Depth  Accuracy  Recall  Precision  F1 score
# 15    400      5  0.744500  0.8200   0.532468  0.645669
# 5     200      5  0.743790  0.8200   0.531605  0.645034
# 0     100      5  0.740241  0.8200   0.527331  0.641879
# 20    500      5  0.742370  0.8175   0.529984  0.643068
# 10    300      5  0.741661  0.8175   0.529126  0.642436
# 16    400     10  0.766501  0.7875   0.563506  0.656934
# 11    300     10  0.765791  0.7875   0.562500  0.656250
# 21    500     10  0.765791  0.7875   0.562500  0.656250
# 1     100     10  0.768630  0.7775   0.567518  0.656118
# 6     200     10  0.764372  0.7775   0.561372  0.651992
# 2     100     15  0.789212  0.7375   0.605749  0.665163
# 7     200     15  0.784954  0.7325   0.599182  0.659168
# 22    500     15  0.790632  0.7250   0.610526  0.662857
# 17    400     15  0.789212  0.7250   0.607966  0.661345
# 12    300     15  0.787793  0.7250   0.605428  0.659841
# 13    300     20  0.790632  0.6975   0.615894  0.654162
# ...

# %%
from sklearn.model_selection import cross_val_score
final_rf = RandomForestClassifier(n_estimators=300, max_depth=10,
                                  random_state=42,class_weight='balanced')

# %%
cv_accuracy = cross_val_score(final_rf, x, y, cv=5, scoring='accuracy')

# %%
cv_accuracy
# Out:
# array([0.7523066 , 0.78495387, 0.75017743, 0.77201705, 0.76704545])

# %%
cv_accuracy.mean()
# Out:
# np.float64(0.765300079843861)

# %%
cv_recall = cross_val_score(final_rf, x, y, cv=5, scoring='recall')

# %%
cv_recall
# Out:
# array([0.72994652, 0.80481283, 0.76203209, 0.78342246, 0.73458445])

# %%
cv_recall.mean()
# Out:
# np.float64(0.762959670829092)

# %%
import matplotlib.pyplot as plt

# %%
y_prob = rf_tuned.predict_proba(x)

# %%
from sklearn.metrics import roc_curve, roc_auc_score
y_prob1 = rf_tuned.predict_proba(X_test)
churn_prob1 = y_prob1[:, 1]
fpr, tpr, thresholds = roc_curve(Y_test, churn_prob1)
auc_score = roc_auc_score(Y_test, churn_prob1)
print("AUC Score:", auc_score)
# Out:
# AUC Score: 0.8420887016848365

# %% [markdown]
# # customer segmentation

# %%
segmentation_data=pd.DataFrame({
    'Tenure Months':x['Tenure Months'],
    'Monthly Charges':x['Monthly Charges'],
    'Total Charges':x['Total Charges'],
    'Churn Probability':y_prob[:,1]
})

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability
# 0                 2            53.85         108.15              0.956
# 1                 2            70.70         151.65              0.948
# 2                 8            99.65         820.50              0.982
# 3                28           104.80        3046.05              0.902
# 4                49           103.70        5036.30              0.882
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40              0.002
# 7039             24            84.80        1990.50              0.034
# 7040             72           103.20        7362.90              0.016
# 7041             11            29.60         346.45              0.208
# 7042             66           105.65        6844.50              0.212
#
# [7043 rows x 4 columns]

# %% [markdown]
# # **implementation of kmeans**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(segmentation_data)

# %%
print(scaled_data[:5])
# Out:
# [[-1.23672422 -0.36266036 -0.9580659   1.69965181]
#  [-1.23672422  0.19736523 -0.93887444  1.67756408]
#  [-0.99240204  1.1595457  -0.64378925  1.77143693]
#  [-0.17799476  1.33071079  0.3380854   1.55055962]
#  [ 0.67713287  1.29415125  1.2161497   1.4953403 ]]

# %%
from sklearn.cluster import KMeans
wcss = []
for k in range(1,16):
  kmeans = KMeans(n_clusters=k, random_state=42)
  kmeans.fit(scaled_data)
  wcss.append(kmeans.inertia_)
plt.figure(figsize=(8,6))
plt.plot(range(1,16),wcss,marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method for Optimal K')
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(scaled_data)

# %%
segmentation_data['Cluster'] = clusters

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability  \
# 0                 2            53.85         108.15              0.956
# 1                 2            70.70         151.65              0.948
# 2                 8            99.65         820.50              0.982
# 3                28           104.80        3046.05              0.902
# 4                49           103.70        5036.30              0.882
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40              0.002
# 7039             24            84.80        1990.50              0.034
# 7040             72           103.20        7362.90              0.016
# 7041             11            29.60         346.45              0.208
# 7042             66           105.65        6844.50              0.212
#
#       Cluster
# 0           2
# 1           2
# 2           2
# 3           2
# 4           0
# ...       ...
# ...

# %%
cluster_summary = segmentation_data.groupby('Cluster').mean()
cluster_summary
# Out:
#          Tenure Months  Monthly Charges  Total Charges  Churn Probability
# Cluster
# 0            57.868793        90.229089    5214.257585           0.188036
# 1            28.499055        36.107164     968.375633           0.103847
# 2            11.615070        73.790422     930.331253           0.776223

# %%
cluster_name ={
    0:"Loyal premium customer",
    1:"Budget Loyal customer",
    2:"High risk customer"
}

# %%
segmentation_data["Cluster Segment"] = segmentation_data["Cluster"].map(cluster_name)

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability  \
# 0                 2            53.85         108.15              0.956
# 1                 2            70.70         151.65              0.948
# 2                 8            99.65         820.50              0.982
# 3                28           104.80        3046.05              0.902
# 4                49           103.70        5036.30              0.882
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40              0.002
# 7039             24            84.80        1990.50              0.034
# 7040             72           103.20        7362.90              0.016
# 7041             11            29.60         346.45              0.208
# 7042             66           105.65        6844.50              0.212
#
#       Cluster         Cluster Segment
# 0           2      High risk customer
# ...

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Tenure Months', y='Churn Probability', hue='Cluster Segment', data=segmentation_data,palette='Spectral')
# Out:
# <Axes: xlabel='Tenure Months', ylabel='Churn Probability'>

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Monthly Charges', y='Churn Probability', hue='Cluster Segment', data=segmentation_data,palette='Spectral')
# Out:
# <Axes: xlabel='Monthly Charges', ylabel='Churn Probability'>
